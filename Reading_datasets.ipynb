# %% [markdown]
# <a href="https://colab.research.google.com/github/Storm00212/machine_learning_classification_RandomForest/blob/main/Reading_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2544c24b-08a5-4102-b90e-7109ee3a6c58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2544c24b-08a5-4102-b90e-7109ee3a6c58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df5 = pd.read_csv('poultry_realistic_health_dataset.csv')
print(df5.describe())
df5.head()
# Out:
#        body_temperature_c  feed_intake_kg  water_intake_l  \
# count          100.000000      100.000000       100.00000
# mean            41.594400        0.126300         0.28280
# std              0.614357        0.028343         0.08786
# min             39.800000        0.080000         0.16000
# 25%             41.167500        0.100000         0.20000
# 50%             41.640000        0.120000         0.27000
# 75%             41.992500        0.150000         0.36250
# max             42.860000        0.180000         0.45000
#
#        daily_mortality_percent
# count               100.000000
# mean                  5.954000
# std                   3.757132
# min                   0.100000
# 25%                   2.575000
# 50%                   6.300000
# 75%                   9.225000
# max                  11.900000
#    body_temperature_c  feed_intake_kg  water_intake_l  \
# 0               40.80            0.11            0.18
# ...

# %%
df6 = pd.read_csv('dairy_realistic_health_dataset.csv')
print(df6.describe())
df6.head()
# Out:
#        body_temperature_c  milk_yield_l  milk_conductivity  feed_intake_kg
# count           100.00000    100.000000         100.000000      100.000000
# mean             38.50520     21.122200           5.878600       11.936700
# std               0.52571      7.175028           1.462077        3.428837
# min              37.12000      8.280000           3.510000        6.040000
# 25%              38.09500     15.092500           4.650000        8.910000
# 50%              38.54000     21.115000           5.680000       11.740000
# 75%              38.89250     27.810000           7.075000       14.900000
# max              39.59000     34.660000           8.410000       17.920000
#    body_temperature_c  milk_yield_l  milk_conductivity  feed_intake_kg  \
# 0               38.47         23.74               4.63            8.91
# 1               38.89         22.10               4.65            6.36
# 2               39.17         15.48               7.81           14.43
# ...

# %%
df7 = pd.read_csv('beef_realistic_health_dataset.csv')
# df7 = df7.drop(columns=["respiratory_rate_bpm","tick_load" ])  uncomment to drop columns
print(df7.describe())
df7.head()
# Out:
#        body_temperature_c  feed_intake_kg  water_intake_l
# count          100.000000      100.000000      100.000000
# mean            38.532200        8.366400       44.771400
# std              0.598555        2.345672       14.522574
# min             37.220000        4.050000       20.070000
# 25%             38.210000        6.755000       33.417500
# 50%             38.520000        8.520000       43.725000
# 75%             38.907500       10.370000       58.060000
# max             39.950000       11.880000       69.960000
#    body_temperature_c  feed_intake_kg  water_intake_l  disease
# 0               39.61           11.82           46.92  Healthy
# 1               38.32            6.15           44.99  Healthy
# 2               38.22            6.31           65.48  Healthy
# 3               38.50           11.45           21.24  Healthy
# 4               38.76           11.27           26.66  Healthy
